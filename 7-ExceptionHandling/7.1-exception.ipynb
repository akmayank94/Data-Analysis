# %% [markdown]
# #### Understanding Exceptions
#
# Exception handling in Python allows you to handle errors gracefully and take corrective actions without stopping the execution of the program. This lesson will cover the basics of exceptions, including how to use try, except, else, and finally blocks.

# %% [markdown]
# ##### What Are Exceptions?
# Exceptions are events that disrupt the normal flow of a program. They occur when an error is encountered during program execution. Common exceptions include:
#
# - ZeroDivisionError: Dividing by zero.
# - FileNotFoundError: File not found.
# - ValueError: Invalid value.
# - TypeError: Invalid type.

# %%
# name error has been raised
a = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # name error has been raised
# ----> 2 a = b
#
# NameError: name 'b' is not defined

# %%
# handling these type of error

# try, except block
try:
    a=b
except:
    print("The variable has not been assigned!")
# Out:
# The variable has not been assigned!

# %%
# handling with the same exception handler
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
# other example

result = 1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 # other example
# ----> 3 result = 1/0
#
# ZeroDivisionError: division by zero

# %%
# if you handle the error incorrectly (eg: Name error happened but try handling with Zerodivision) so it will give error and not statement
try:
    a = 1/0
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the denominator > 0")
# Out:
# division by zero
# Please enter the denominator > 0

# %%
# using base class of exception for every type
# Exception is the parent class of all type of exceptions
try:
    result = 1/2
    a = b
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the denominator > 0")

except Exception as ex1:
    print(ex1)
    print("main exception got caught")
# Out:
# name 'b' is not defined
# main exception got caught

# %%
# example of handling errors
try:
    num = int(input("Enter a number:"))
    result = 10/num

except ValueError:
    print("This is not a valid number")

except ZeroDivisionError:
    print("Enter denominator > 0")

except Exception as ex:
    print(ex)
# Out:
# This is not a valid number

# %%
# try, except, else block

# else ->  get executed when try works sucessfully
try:
    num = int(input("Enter a number:"))
    result = 10/num

except ValueError:
    print("This is not a valid number")

except ZeroDivisionError:
    print("Enter denominator greater than 0")

except Exception as ex:
    print(ex)

else:
    print("The result is ",result)
# Out:
# Enter denominator greater than 0

# %%
# try, except, else and finally block

# finally -> always get executed whether error occurs or not
try:
    num = int(input("Enter a number:"))
    result = 10/num

except ValueError:
    print("This is not a valid number")

except ZeroDivisionError:
    print("Enter denominator > 0")

except Exception as ex:
    print(ex)

else:
    print("The result is ",result)

finally:
    print("Execution completed!")
# Out:
# The result is  0.9090909090909091
# Execution completed!

# %% [markdown]
# SOME PRACTICAL EXAMPLES

# %%
# File handling and Exception handling

try:
    file = open('example.txt','r')
    content = file.read()
    a=b
    print(content)

except FileNotFoundError:
    print("The file does not exist!")

except Exception as ex:
    print(ex)

finally:
    if 'file' in locals() or not file.closed():
        file.close()
        print("File Closed!")
# Out:
# name 'b' is not defined
# File Closed!
